# %%
## Install any libraries not commonly used
# 1. pip install pygal

# Import the pathlib and csv library
from pathlib import Path
import pandas as pd
import numpy as np
import pygal
import csv
import panel as pn
pn.extension('plotly')
import plotly.express as px
import hvplot.pandas
import matplotlib.pyplot as plt
import os

# Set the file paths

crypto_path = Path("Data/crypto_user_growth_aus.csv")
gym_est_path = Path("Data/gym_establishments.csv")
gym_user_path = Path("Data/gym_users.csv")
total_ops_path = Path("Data/total_operational_savings.csv")
bitcoin_path = Path("Data/coin_bitcoin.csv")
crypto_wallet_users_path = Path("Data/my-wallet-n-users.csv")

# %%
# Reading in the crypto user growth
## Display Crypto user dataframe

crypto_user = pd.read_csv(crypto_path, index_col="year")
crypto_user
# Out:
#        growth
# year
# 2019     16.8
# 2020     18.4
# 2021     28.8

# %%
crypto_user.dtypes
# Out:
#  growth    float64
# dtype: object

# %%
# Reading in the gym establishments
## Display gym establishments dataframe

gym_est = pd.read_csv(gym_est_path, index_col="year")
gym_est
# Out:
#       no_of_gyms
# year
# 2016        3900
# 2017        4400
# 2018        4800
# 2019        5000
# 2020        5300

# %%
# Reading in the gym user
## Display gym user dataframe

gym_user = pd.read_csv(gym_user_path, index_col = "age")
gym_user
# Out:
#         No  number_of_people
# age
# 15-17    1            263000
# 18-24    2           1103000
# 25-35    3           1720000
# 35-44    4           1367000
# 45-54    5           1151000
# 55-64    6            948000
# 65-120   7           1312000

# %%
# Reading in the total opertational savings
## Display gtotal operational savings dataframe

total_ops = pd.read_csv(total_ops_path)
total_ops
# Out:
#     no   Transaction_Amount   Price_Old   Total_Cost   Hedera   Total_Cost.1  \
# 0    1                  100        0.88           88  0.00014          0.014
# 1    1                 1000        0.88          888  0.00014          0.140
# 2    1                10000        0.88         8888  0.00014          1.140
# 3    1               100000        0.88        88888  0.00014         11.400
# 4    2                  100        0.51           51  0.00014          0.014
# 5    2                 1000        0.51          510  0.00014          0.140
# 6    2                10000        0.51         5100  0.00014          1.400
# 7    2               100000        0.51        51000  0.00014         11.400
# 8    3                  100        0.44           44  0.00014          0.014
# 9    3                 1000        0.44          440  0.00014          0.140
# 10   3                10000        0.44         4400  0.00014          1.400
# ...

# %%
df_bitcoin = pd.read_csv(bitcoin_path)
df_bitcoin.head()
df_bitcoin.drop['SNo']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15172/2735409455.py in <module>
#       1 df_bitcoin = pd.read_csv(bitcoin_path)
#       2 df_bitcoin.head()
# ----> 3 df_bitcoin.drop['SNo']
#
# TypeError: 'method' object is not subscriptable

# %%
df_cryptowallet_user = pd.read_csv(crypto_wallet_users_path)
df_cryptowallet_user.head()
# Out:
#              Timestamp  my-wallet-n-users
# 0  2011-11-29 00:00:00                  2
# 1  2011-12-21 00:00:00                265
# 2  2012-01-12 00:00:00                710
# 3  2012-02-03 00:00:00               1425
# 4  2012-02-25 00:00:00               2159

# %%
bitcoin_and_wallet_users = pd.concat(['df_bitcoin','df_cryptowallet_user'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15172/1427740664.py in <module>
# ----> 1 bitcoin_and_wallet_users = pd.concat(['df_bitcoin','df_cryptowallet_user'])
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     302         verify_integrity=verify_integrity,
#     303         copy=copy,
# --> 304         sort=sort,
#     305     )
#     306
#
# ...

# %%
bitcoin_plot = df_bitcoin.hvplot(x='Date', y=['High','Close'], width=800, height=500, 
                            line_width= 5, groupby='Symbol',widget_location='top_left', yformatter='%.0f',xlabel='Year',ylabel='Average House Value Price',
                                       fontscale=1.5)
bitcoin_plot
# Out:
# Column
#     [0] Row
#         [0] WidgetBox
#             [0] Select(margin=(20, 20, 20, 20), name='Symbol', options=['BTC'], value='BTC', width=250)
#         [1] HSpacer()
#     [1] HoloViews(DynamicMap, widget_location='top_left')

# %%
bitcoin_plot = df_bitcoin.hvplot.line(x='Date', y='High', width = 1200, height = 300)
bitcoin_plot
# Out:
# :Curve   [Date]   (High)

# %%
# Utilising pygal to plot a bar chart
## Display pygal bar for crypto user

# Create a bar grapth object
crypto_line = pygal.Line()

# Create bar graph
crypto_line.title = "Crypto User Growth"
crypto_line.add('growth',[18.4,28.8])
crypto_line.render()
# Out:
# b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-f89f9be4-c0ce-456d-a045-38a177fcb03b" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2022-02-15--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-f89f9be4-c0ce-456d-a045-38a177fcb03b{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-f89f9be4-c0ce-456d-a045-38a177fcb03b .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-f89f9be4-c0ce-456d-a045-38a177fcb03b .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-f89f9be4-c0ce-456d-a045-38a177fcb03b .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-f89f9be4-c0ce-456d-a045-38a177fcb
# ...
