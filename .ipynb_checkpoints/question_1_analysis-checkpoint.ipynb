# %%
# Import the pathlib and csv library
from pathlib import Path
import pandas as pd
import pygal
import csv

# Set the file paths

crypto_path = Path("Data/crypto_user_growth_aus.csv")
gym_est_path = Path("Data/gym_establishments.csv")
gym_user_path = Path("Data/gym_users.csv")
total_ops_path = Path("Data/total_operational_savings.csv")

# %%
# Reading in the crypto user growth
## Display Crypto user dataframe

crypto_user = pd.read_csv(crypto_path, index_col="year")
crypto_user
# Out:
#        growth
# year
# 2020     18.4
# 2021     28.8

# %%
crypto_user.dtypes
# Out:
#  growth    float64
# dtype: object

# %%
# Reading in the gym establishments
## Display gym establishments dataframe

gym_est = pd.read_csv(gym_est_path, index_col="year")
gym_est
# Out:
#       no_of_gyms
# year
# 2016        3900
# 2017        4400
# 2018        4800
# 2019        5000
# 2020        5300

# %%
# Reading in the gym user
## Display gym user dataframe

gym_user = pd.read_csv(gym_user_path, index_col = "age")
gym_user
# Out:
#         No  number_of_people
# age
# 15-17    1            263000
# 18-24    2           1103000
# 25-35    3           1720000
# 35-44    4           1367000
# 45-54    5           1151000
# 55-64    6            948000
# 65-120   7           1312000

# %%
# Reading in the total opertational savings
## Display gtotal operational savings dataframe

total_ops = pd.read_csv(total_ops_path)
total_ops
# Out:
#     no   Transaction_Amount   Price_Old   Total_Cost   Hedera   Total_Cost.1  \
# 0    1                  100        0.88           88  0.00014          0.014
# 1    1                 1000        0.88          888  0.00014          0.140
# 2    1                10000        0.88         8888  0.00014          1.140
# 3    1               100000        0.88        88888  0.00014         11.400
# 4    2                  100        0.51           51  0.00014          0.014
# 5    2                 1000        0.51          510  0.00014          0.140
# 6    2                10000        0.51         5100  0.00014          1.400
# 7    2               100000        0.51        51000  0.00014         11.400
# 8    3                  100        0.44           44  0.00014          0.014
# 9    3                 1000        0.44          440  0.00014          0.140
# 10   3                10000        0.44         4400  0.00014          1.400
# 11   3               100000        0.44        44000  0.00014         11.400
#
#       Savings
# 0      87.986
# 1     879.860
# 2    8798.600
# 3   87986.000
# 4      50.986
# 5     509.860
# 6    5098.600
# 7   50986.000
# 8      43.986
# 9     439.860
# 10   4398.600
# 11  43986.000

# %%
# Utilising pygal to plot a bar chart
## Display pygal bar for crypto user

# Create a bar grapth object
crypto_line = pygal.Line()

# Create bar graph
crypto_line.title = "Crypto User Growth"
crypto_line.add('growth',[18.4,28.8])
crypto_line.render()
# Out:
# b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-fef1fb31-8a66-4b94-bb33-5a209fa77464" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2022-02-12--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464{background-color:rgba(249,249,249,1)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 path,#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 line,#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 rect,#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .graph{fill:rgba(0,0,0,.87)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 text.no_data{fill:rgba(0,0,0,1)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .title{fill:rgba(0,0,0,1)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .axis .line{stroke:rgba(0,0,0,1)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .axis text.major{fill:rgba(0,0,0,1)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .axis.y .guides:hover .guide.line,#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .line-graph .axis.x .guides:hover .guide.line,#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .ci{stroke:rgba(0,0,0,.87)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .reactive.active,#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .ci .reactive.active{stroke-width:1.5}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .series text{fill:rgba(0,0,0,1)}#chart-fef1fb31-8a66-4b94-bb33-5a209fa77464 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-m ...
